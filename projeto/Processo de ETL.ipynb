# %% [markdown]
# # Importação das bibliotecas

# %%
#Importações de bibliotecas

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Configuração das bibliotecas

# %%
pd.reset_option('display.max_colwidth')

# %% [markdown]
# # importação dos CSV e transformando em datasets pandas

# %%
gruposDFnomeDasColunas = [
    "nome",
    "classificacao",
    "frequencia_feminina",
    "frequencia_masculina",
    "frequencial_total",
    "proporcao",
    "nomes_alternativos"    
]
gruposDF = pd.read_csv('grupos.csv', names=gruposDFnomeDasColunas, header=0)
gruposDF.head()
# Out:
#     nome classificacao  frequencia_feminina  frequencia_masculina  \
# 0  ALINE             F               528515                  2035
# 1   ARAO             M                    0                  3526
# 2   ARON             M                    0                  3442
# 3    ADA             F                 5294                   289
# 4  ABADE             M                    0                    57
#
#    frequencial_total  proporcao  \
# 0             530550   0.996164
# 1               3526   1.000000
# 2               3442   1.000000
# 3               5583   0.948236
# 4                 57   1.000000
#
#                                   nomes_alternativos
# 0  |AALINE|AILINE|ALEINE|ALIINE|ALINE|ALINER|ALIN...
# 1                                 |AARAO|ARAAO|ARAO|
# 2               |AARON|AHARON|AROM|ARON|ARYON|HARON|
# 3                      |ABA|ADA|ADAH|ADAR|ADHA|HADA|
# 4                                            |ABADE|

# %%
nomesDSnomeDasColunas = [
    "nomes_alternativos",
    "classificacao",
    "primeiro_nome",
    "frequencia_feminina",
    "frequencia_masculina",
    "frequencia_total",
    "frequencia_grupo",
    "nome_grupo",
    "proporcao"
]
nomesDF= pd.read_csv("nomes.csv",names=nomesDSnomeDasColunas,header=0)
nomesDF.head()
# Out:
#                                   nomes_alternativos classificacao  \
# 0  AILINE|ALEINE|ALIINE|ALINE|ALINER|ALINHE|ALINN...             F
# 1                                         ARAAO|ARAO             M
# 2                       AHARON|AROM|ARON|ARYON|HARON             M
# 3                            ADA|ADAH|ADAR|ADHA|HADA             F
# 4                                                NaN             M
#
#   primeiro_nome  frequencia_feminina  frequencia_masculina  frequencia_total  \
# 0        AALINE                 66.0                   NaN                66
# 1         AARAO                  NaN                 281.0               281
# 2         AARON                  NaN                 676.0               676
# 3           ABA                 82.0                   NaN                82
# 4         ABADE                  NaN                  57.0                57
#
#    frequencia_grupo nome_grupo  proporcao
# 0            530550      ALINE        1.0
# 1              3526       ARAO        1.0
# 2              3442       ARON        1.0
# 3              5583        ADA        1.0
# 4                57      ABADE        1.0

# %% [markdown]
# # Limpeza de nulos e n/a

# %%
gruposDF.fillna(0, inplace=True)
nomesDF.fillna(0, inplace=True)

gruposDF.drop_duplicates(inplace=True)
nomesDF.drop_duplicates(inplace=True)

# %% [markdown]
# # Unir dataframes

# %%
gruposSelecionado= gruposDF[['nome', 'frequencia_feminina', 'frequencia_masculina', 'classificacao']]
nomesSelecionado = nomesDF[['primeiro_nome', 'frequencia_feminina', 'frequencia_masculina', 'classificacao']]

# %%
nomesSelecionado = nomesSelecionado.rename(columns={'primeiro_nome': 'nome'})

# %%
nomesSelecionado.head()
# Out:
#      nome  frequencia_feminina  frequencia_masculina classificacao
# 0  AALINE                 66.0                   0.0             F
# 1   AARAO                  0.0                 281.0             M
# 2   AARON                  0.0                 676.0             M
# 3     ABA                 82.0                   0.0             F
# 4   ABADE                  0.0                  57.0             M

# %%
gruposSelecionado.head()
# Out:
#     nome  frequencia_feminina  frequencia_masculina classificacao
# 0  ALINE               528515                  2035             F
# 1   ARAO                    0                  3526             M
# 2   ARON                    0                  3442             M
# 3    ADA                 5294                   289             F
# 4  ABADE                    0                    57             M

# %%
data =  pd.merge(gruposSelecionado, nomesSelecionado, on='nome', how='outer')

# %%
data.drop_duplicates(subset='nome', keep='first', inplace=True)

# %% [markdown]
# # Formatação e encoding

# %%
data['frequenciaFeminina'] = data['frequencia_feminina_x'] + data['frequencia_feminina_y']
data['frequenciaMasculina'] = data['frequencia_masculina_x'] + data['frequencia_masculina_y']
data.head()
# Out:
#     nome  frequencia_feminina_x  frequencia_masculina_x classificacao_x  \
# 0  ALINE               528515.0                  2035.0               F
# 1   ARAO                    0.0                  3526.0               M
# 2   ARON                    0.0                  3442.0               M
# 3    ADA                 5294.0                   289.0               F
# 4  ABADE                    0.0                    57.0               M
#
#    frequencia_feminina_y  frequencia_masculina_y classificacao_y  \
# 0               509869.0                  1868.0               F
# 1                    0.0                  3078.0               M
# 2                    0.0                  2269.0               M
# 3                 5029.0                   266.0               F
# 4                    0.0                    57.0               M
#
#    frequenciaFeminina  frequenciaMasculina
# 0           1038384.0               3903.0
# 1                 0.0               6604.0
# 2                 0.0               5711.0
# 3             10323.0                555.0
# 4                 0.0                114.0

# %%
# Manter apenas as colunas de interesse
data = data[['nome', 'frequenciaFeminina', 'frequenciaMasculina', 'classificacao_x']]
data.rename(columns={'classificacao_x': 'classificacao'}, inplace=True)
data.head()
# Out:
#     nome  frequenciaFeminina  frequenciaMasculina classificacao
# 0  ALINE           1038384.0               3903.0             F
# 1   ARAO                 0.0               6604.0             M
# 2   ARON                 0.0               5711.0             M
# 3    ADA             10323.0                555.0             F
# 4  ABADE                 0.0                114.0             M

# %%
labelEncoder = LabelEncoder()
data['classificacaoCodificada'] = labelEncoder.fit_transform(data['classificacao'])
data.head()
# Out:
#     nome  frequenciaFeminina  frequenciaMasculina classificacao  \
# 0  ALINE           1038384.0               3903.0             F
# 1   ARAO                 0.0               6604.0             M
# 2   ARON                 0.0               5711.0             M
# 3    ADA             10323.0                555.0             F
# 4  ABADE                 0.0                114.0             M
#
#    classificacaoCodificada
# 0                        0
# 1                        1
# 2                        1
# 3                        0
# 4                        1

# %%
#F = 0
#M = 1
data.drop(columns=["classificacao"], inplace=True)

# %% [markdown]
# # Salvar CSV

# %%
data.to_csv('data.csv', index=False)
