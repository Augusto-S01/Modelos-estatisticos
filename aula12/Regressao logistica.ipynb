# %% [markdown]
# # 1.Objetivo

# %% [markdown]
# Utilizar a base de dados pima-indians-diabetes.data.csv e a biblioteca scikit-learn para realizar uma regressão logística.

# %% [markdown]
# # 2.Variaveis

# %% [markdown]
# Variável Dependente (Alvo): Class
#
# Variáveis Independentes: Todas as outras variáveis do conjunto de dados.

# %% [markdown]
# # 3.Tarefas

# %% [markdown]
# Realizar a regressão logística.
#
# Realizar o pré-processamento e a Análise Exploratória dos Dados.
#
# Calcular e apresentar os seguintes parâmetros para medir o desempenho:
#
# - Acurácia
#
# - Precisão
#
# - Recuperação
#
# - F1 Score

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy import stats

# %%
dataframe = pd.read_csv("pima-indians-diabetes.data.csv")
dataframe.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    Pedigree  Age  Class
# 0       627   50      1
# 1       351   31      0
# 2       672   32      1
# 3       167   21      0
# 4      2288   33      1

# %%
dataframe.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      Pedigree  Age  Class
# 0         627   50      1
# 1         351   31      0
# 2         672   32      1
# ...

# %%
X = dataframe.drop('Class',axis=1)
Y = dataframe['Class']

# %%
X_treino, X_teste , Y_treino , Y_teste = train_test_split(X, Y, test_size=0.3, random_state=42, stratify=Y)

# %%
scaler = StandardScaler()
X_treino_escalonado = scaler.fit_transform(X_treino)
X_teste_escalonado = scaler.transform(X_teste)

# %%
modelo = LogisticRegression(max_iter=1000)
modelo.fit(X_treino_escalonado,Y_treino)
# Out:
# LogisticRegression(max_iter=1000)

# %%
Y_predicao = modelo.predict(X_teste_escalonado)

# %%
acuracia = accuracy_score(Y_teste, Y_predicao)
precisao = precision_score(Y_teste, Y_predicao)
recall = recall_score(Y_teste, Y_predicao)
f1 = f1_score(Y_teste, Y_predicao)

# %%
print(f"Acurácia: {acuracia:.2f}")
print(f"Precisão: {precisao:.2f}")
print(f"Recuperação (Recall): {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
# Out:
# Acurácia: 0.74
# Precisão: 0.68
# Recuperação (Recall): 0.52
# F1 Score: 0.59
