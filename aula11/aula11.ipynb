# %% [markdown]
# # importanto bibliotecas

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from scipy import stats

# %% [markdown]
# # importando csv

# %%
dataframe = pd.read_csv("titanic.csv")
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# limpando dados

# %%
dataframe.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data = dataframe.dropna()

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # visualização e transformação de labels

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
data.nunique()
# Out:
# PassengerId    183
# Survived         2
# Pclass           3
# Name           183
# Sex              2
# Age             63
# SibSp            4
# Parch            4
# Ticket         127
# Fare            93
# Cabin          133
# Embarked         3
# dtype: int64

# %%
data["Sex"].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
labelEncoder = LabelEncoder()

# %%
data["Sex"] = labelEncoder.fit_transform(data["Sex"])
# Out:
# /tmp/ipykernel_2735/2268244237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Sex"] = labelEncoder.fit_transform(data["Sex"])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 6                             McCarthy, Mr. Timothy J    1  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut    0   4.0      1
# 11                           Bonnell, Miss. Elizabeth    0  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
data["Embarked"].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
data["Embarked"] = labelEncoder.fit_transform(data["Embarked"])
# Out:
# /tmp/ipykernel_2735/2411012067.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Embarked"] = labelEncoder.fit_transform(data["Embarked"])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 6                             McCarthy, Mr. Timothy J    1  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut    0   4.0      1
# 11                           Bonnell, Miss. Elizabeth    0  58.0      0
#
#     Parch    Ticket     Fare Cabin  Embarked
# 1       0  PC 17599  71.2833   C85         0
# 3       0    113803  53.1000  C123         2
# 6       0     17463  51.8625   E46         2
# 10      1   PP 9549  16.7000    G6         2
# 11      0    113783  26.5500  C103         2

# %% [markdown]
# # Visualização dos dados em graficos

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name  Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 6                             McCarthy, Mr. Timothy J    1  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut    0   4.0      1
# 11                           Bonnell, Miss. Elizabeth    0  58.0      0
#
#     Parch    Ticket     Fare Cabin  Embarked
# 1       0  PC 17599  71.2833   C85         0
# 3       0    113803  53.1000  C123         2
# 6       0     17463  51.8625   E46         2
# 10      1   PP 9549  16.7000    G6         2
# 11      0    113783  26.5500  C103         2

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Pclass', y='Age', data=data)
plt.title('Boxplot da Idade por Classe')
plt.xlabel('Classe')
plt.ylabel('Idade')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Survived', y='Age', data=data)
plt.title('Boxplot da Survived por Idade')
plt.xlabel('Survived')
plt.ylabel('Idade')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=10, kde=True)
plt.title('Histograma da Idade dos Passageiros')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Fare', data=data, hue='Survived', style='Pclass', palette='viridis', s=100)
plt.title('Scatterplot da Idade vs. Tarifa')
plt.xlabel('Idade')
plt.ylabel('Tarifa')
plt.legend(title='Sobrevivente / Classe')
plt.show()

# %%
colunasNumericas = ['Age', 'Fare', 'SibSp', 'Parch']

# Criar o pair plot
sns.pairplot(data[colunasNumericas])
plt.suptitle('Pair Plot das Variáveis Numéricas', y=1.02)
plt.show()

# %% [markdown]
# # Regressao linear e Tratamento de sampling

# %% [markdown]
# ## importando modulos

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix , classification_report
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Divida os dados em conjuntos de teste e treinamento

# %%
X_treino ,X_teste , Y_treino , Y_teste = train_test_split(data[['PassengerId', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']] , data[['Survived']], test_size=0.2, random_state=42)

# %%
print('Antes o oversampling,forma do X_treino : {}'.format(X_treino.shape))
print('Antes o oversampling,forma do Y_treino : {}'.format(Y_treino.shape))

print('Antes o oversampling, contagem de rotulo "1": {}'.format(np.sum(Y_treino == 1)))
print('Antes o oversampling, contagem do rotulo "0": {}'.format(np.sum(Y_treino == 0)))
# Out:
# Antes o oversampling,forma do X_treino : (146, 8)
# Antes o oversampling,forma do Y_treino : (146, 1)
# Antes o oversampling, contagem de rotulo "1": Survived    100
# dtype: int64
# Antes o oversampling, contagem do rotulo "0": Survived    46
# dtype: int64

# %%
lr = LogisticRegression()
lr.fit(X_treino,Y_treino)
predictions = lr.predict(X_teste)


print(classification_report(Y_teste,predictions))
print(confusion_matrix(Y_teste,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.57      0.64        14
#            1       0.77      0.87      0.82        23
#
#     accuracy                           0.76        37
#    macro avg       0.75      0.72      0.73        37
# weighted avg       0.75      0.76      0.75        37
#
# [[ 8  6]
#  [ 3 20]]
# /home/augusto/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/augusto/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...

# %%
# !pip install imblearn

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state = 2 )

# %%
X_treino_res , Y_treino_res = sm.fit_resample(X_treino, Y_treino) 
print('Apos o oversampling,forma do X_treino : {}'.format(X_treino_res.shape))
print('Apos o oversampling,forma do Y_treino : {}'.format(Y_treino_res.shape))

print('Apos o oversampling, contagem de rotulo "1": {}'.format(np.sum(Y_treino_res == 1)))
print('Apos o oversampling, contagem do rotulo "0": {}'.format(np.sum(Y_treino_res == 0)))
# Out:
# Apos o oversampling,forma do X_treino : (200, 8)
# Apos o oversampling,forma do Y_treino : (200, 1)
# Apos o oversampling, contagem de rotulo "1": Survived    100
# dtype: int64
# Apos o oversampling, contagem do rotulo "0": Survived    100
# dtype: int64

# %%
lr = LogisticRegression()
lr.fit(X_treino_res,Y_treino_res)
predictions = lr.predict(X_teste)


print(classification_report(Y_teste,predictions))
print(confusion_matrix(Y_teste,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.86      0.73        14
#            1       0.89      0.70      0.78        23
#
#     accuracy                           0.76        37
#    macro avg       0.76      0.78      0.75        37
# weighted avg       0.79      0.76      0.76        37
#
# [[12  2]
#  [ 7 16]]
# /home/augusto/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1229: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/augusto/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# ...
